# %% [markdown]
# # example
#
# Edit this notebook locally, then `make push P=example` to run it on Kaggle.
#
# The first cell of the *pushed* copy is added automatically and puts `src/` on the import path — you will not see it here.

# %%
import os, sys

print('python', sys.version.split()[0])
print('running on kaggle:', os.path.isdir('/kaggle/input'))

# %%
from example_lib import describe

print(describe('example'))

# %% [markdown]
# ## Outputs
#
# Anything written to `/kaggle/working/` comes back with `make output`.

# %%
from pathlib import Path

out = Path('/kaggle/working') if os.path.isdir('/kaggle/working') else Path('.')
(out / 'result.txt').write_text('it works\n')
print('wrote', out / 'result.txt')
